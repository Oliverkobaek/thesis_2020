# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats
import scipy.optimize
sns.set()

# %%
pd.set_option('precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_læsø =  pd.read_csv('https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/Bresnahan/L%C3%A6s%C3%B8.csv')
år = list(range(2008,2019))
df_læsø['år'] = år
df_læsø.rename(columns = {'kommune': 'Kommune', 'år': 'År'}, inplace = True)

# %%
df_2008 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2008.csv")
df_2008_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2008.csv")
df_2009 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2009.csv")
df_2009_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2009.csv")
df_2010 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2010.csv")
df_2010_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2010.csv")
df_2011 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2011.csv")
df_2011_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2011.csv")
df_2012 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2012.csv")
df_2012_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2012.csv")
df_2013 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2013.csv")
df_2013_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2013.csv")
df_2014 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2014.csv")
df_2014_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2014.csv")
df_2015 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2015.csv")
df_2015_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2015.csv")
df_2016 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2016.csv")
df_2016_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2016.csv")
df_2017 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2017.csv")
df_2017_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2017.csv")
df_2018 =  pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/APOTEK_ny_u_UDS_M_OMS_M_IND_2018.csv")
df_2018_ny = pd.read_csv("https://raw.githubusercontent.com/Oliverkobaek/thesis_2020/master/%C3%85rsdata/Ny/APOTEK_ny2_u_UDS_M_OMS_M_IND_inf_2018.csv")

#df_komkode =  pd.read_excel("C:/Users/Oliver/Desktop/11. Semester/DATA/Bresnahan/kommunekode.xlsx")
#df_befolkning_kode = df_befolkning.merge(df_komkode, left_on='Kommune', right_on='Kommune')

# %%
df_2008_ny['antal_apo']=df_2008_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2008_ny['År'] = 2008
df_2009_ny['antal_apo']=df_2009_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2009_ny['År'] = 2009
df_2010_ny['antal_apo']=df_2010_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2010_ny['År'] = 2010
df_2011_ny['antal_apo']=df_2011_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2011_ny['År'] = 2011
df_2012_ny['antal_apo']=df_2012_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2012_ny['År'] = 2012
df_2013_ny['antal_apo']=df_2013_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2013_ny['År'] = 2013
df_2014_ny['antal_apo']=df_2014_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2014_ny['År'] = 2014
df_2015_ny['antal_apo']=df_2015_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2015_ny['År'] = 2015
df_2016_ny['antal_apo']=df_2016_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2016_ny['År'] = 2016
df_2017_ny['antal_apo']=df_2017_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2017_ny['År'] = 2017
df_2018_ny['antal_apo']=df_2018_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2018_ny['År'] = 2018

# %%
df_2008_reduced = df_2008_ny.drop_duplicates(subset=['Kommune'])
df_2009_reduced = df_2009_ny.drop_duplicates(subset=['Kommune'])
df_2010_reduced = df_2010_ny.drop_duplicates(subset=['Kommune'])
df_2011_reduced = df_2011_ny.drop_duplicates(subset=['Kommune'])
df_2012_reduced = df_2012_ny.drop_duplicates(subset=['Kommune'])
df_2013_reduced = df_2013_ny.drop_duplicates(subset=['Kommune'])
df_2014_reduced = df_2014_ny.drop_duplicates(subset=['Kommune'])
df_2015_reduced = df_2015_ny.drop_duplicates(subset=['Kommune'])
df_2016_reduced = df_2016_ny.drop_duplicates(subset=['Kommune'])
df_2017_reduced = df_2017_ny.drop_duplicates(subset=['Kommune'])
df_2018_reduced = df_2018_ny.drop_duplicates(subset=['Kommune'])

# %%
df_bres_2008_ny = df_2008_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2009_ny = df_2009_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2010_ny = df_2010_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2011_ny = df_2011_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2012_ny = df_2012_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2013_ny = df_2013_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2014_ny = df_2014_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2015_ny = df_2015_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2016_ny = df_2016_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2017_ny = df_2017_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2018_ny = df_2018_reduced.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)

# %%
df_bres_2018_ny
# Out:
#      Kommune  ALDER       d65       d17    samlet_ind      Besk  Besk1864  \
# 0        101  35.45  0.102927  0.175385  219838.02190  0.556601  0.739809
# 35       147  39.31  0.170537  0.176780  247917.78922  0.539111  0.778739
# 45       151  41.71  0.206963  0.212246  195141.23211  0.478851  0.764392
# 50       153  40.98  0.191739  0.209566  168886.78874  0.457004  0.709531
# 53       155  43.83  0.243868  0.226419  245042.36065  0.490812  0.826427
# ..       ...    ...       ...       ...           ...       ...       ...
# 447      840  40.93  0.193508  0.238835  199586.39944  0.516623  0.818713
# 450      846  43.51  0.225395  0.197289  177052.87973  0.489407  0.760894
# 453      849  43.69  0.239288  0.203224  166061.77609  0.479398  0.765624
# 457      851  39.46  0.178011  0.181379  182117.68051  0.491668  0.716766
# 477      860  43.69  0.231331  0.195175  170647.52008  0.483361  0.755866
#
#            DK  Befolkning  markedsvaerdix  yderkom  antal_apo    År
# ...

# %%
frames = [ df_bres_2008_ny, df_bres_2009_ny, df_bres_2010_ny, df_bres_2011_ny,df_bres_2012_ny,df_bres_2013_ny,df_bres_2014_ny,df_bres_2015_ny,df_bres_2016_ny,df_bres_2017_ny,df_bres_2018_ny, df_læsø]#df_bres_2010, df_bres_2011, df_bres_2012, df_bres_2013, df_bres_2014, df_bres_2015, df_bres_2016, df_bres_2017, df_bres_2018]
df_bres_samlet_ny = pd.concat(frames)
df_bres_samlet_ny.to_csv('Bresnahan_data_full_læsø.csv')

# %%
df_bres_samlet_ny
# Out:
#     Kommune  ALDER  d65  d17  samlet_ind  Besk  Besk1864   DK  Befolkning  \
# 0       101  36.10 0.11 0.17   197499.87  0.55      0.73 0.79      518574
# 26      147  39.68 0.16 0.17   221333.09  0.54      0.76 0.85       95029
# 31      151  40.04 0.18 0.23   186155.49  0.49      0.77 0.88       47398
# 34      153  40.57 0.18 0.22   172691.88  0.48      0.73 0.76       33762
# 36      155  42.38 0.20 0.23   220357.76  0.51      0.82 0.94       13411
# ..      ...    ...  ...  ...         ...   ...       ...  ...         ...
# 6       825  51.74 0.35 0.14   154652.82  0.47      0.73 0.93        1795
# 7       825  51.80 0.36 0.14   156511.19  0.47      0.74 0.92        1817
# 8       825  52.28 0.37 0.13   158750.32  0.47      0.75 0.92        1793
# 9       825  52.95 0.38 0.13   165000.49  0.48      0.75 0.91        1807
# 10      825  53.05 0.39 0.13   166023.23  0.49      0.76 0.91        1806
#
#     markedsvaerdix  yderkom  antal_apo    År
# ...

# %%
#df_befolkning_kode = df_befolkning.merge(df_komkode, left_on='Kommune', right_on='Kommune')

# %%
# Okay, hvad er jeg interesseret i?
# Jeg er interesseret i at oprette en ny dataframe der har: 
# Antal i hver kommune kode = marked
# alle lov modellens variable vil være det samme i hvert marked på den måde?

# Jeg starter med at kigge på et enkelt år
#df_pop_2008 = df_befolkning[['Kommune', 'Kode','2008']]
#df_pop_2009 = df_befolkning[['Kommune', 'Kode','2009']]
# df_pop_2010 = df_befolkning[['Kommune', 'Kode','2010']]
# df_pop_2010.columns = ['Kommune', 'Kode','Befolkning']
# df_pop_2010['År'] = 2010
# df_pop_2011 = df_befolkning[['Kommune', 'Kode','2011']]
# df_pop_2011.columns = ['Kommune', 'Kode','Befolkning']
# df_pop_2011['År'] = 2011
# df_pop_2012 = df_befolkning[['Kommune', 'Kode','2012']]
# df_pop_2012.columns = ['Kommune', 'Kode','Befolkning']
# df_pop_2012['År'] = 2012
# df_pop_2013 = df_befolkning[['Kommune', 'Kode','2013']]
# df_pop_2013.columns = ['Kommune', 'Kode','Befolkning']
# df_pop_2013['År'] = 2013
# df_pop_2014 = df_befolkning[['Kommune', 'Kode','2014']]
# df_pop_2014.columns = ['Kommune', 'Kode','Befolkning']
# df_pop_2014['År'] = 2014
df_pop_2015 = df_befolkning[['Kommune', 'Kode','2015']]
df_pop_2015.columns = ['Kommune', 'Kode','Befolkning']
df_pop_2015['År'] = 2015
df_pop_2016 = df_befolkning[['Kommune', 'Kode','2016']]
df_pop_2016.columns = ['Kommune', 'Kode','Befolkning']
df_pop_2016['År'] = 2016
df_pop_2017 = df_befolkning[['Kommune', 'Kode','2017']]
df_pop_2017.columns = ['Kommune', 'Kode','Befolkning']
df_pop_2017['År'] = 2017
df_pop_2018 = df_befolkning[['Kommune', 'Kode','2018']]
df_pop_2018.columns = ['Kommune', 'Kode','Befolkning']
df_pop_2018['År'] = 2018

# 
#df_pop_2018 = df_pop_2018.astype({'Kommune': int})
# Tæller antal apoteker i hver kommune
#df_2008['antal_apo']=df_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
#df_2009['antal_apo']=df_ny.groupby(by='Kommune')['ApotekNr'].transform('count')
# df_2010['antal_apo']=df_2010.groupby(by='Kommune')['ApotekNr'].transform('count')
# df_2011['antal_apo']=df_2011.groupby(by='Kommune')['ApotekNr'].transform('count')
# df_2012['antal_apo']=df_2012.groupby(by='Kommune')['ApotekNr'].transform('count')
# df_2013['antal_apo']=df_2013.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2014['antal_apo']=df_2014.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2015['antal_apo']=df_2015.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2016['antal_apo']=df_2016.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2017['antal_apo']=df_2017.groupby(by='Kommune')['ApotekNr'].transform('count')
df_2018['antal_apo']=df_2018.groupby(by='Kommune')['ApotekNr'].transform('count')

# Merge populations data med apoteksdata
#df_2008_pop = df_2008.merge(df_pop_2008, left_on='Kommune', right_on='Kode')
#df_2009_pop = df_2009.merge(df_pop_2009, left_on='Kommune', right_on='Kode')
#df_2010_pop = df_2010.merge(df_pop_2010, left_on='Kommune', right_on='Kode')
# df_2011_pop = df_2011.merge(df_pop_2011, left_on='Kommune', right_on='Kode')
# df_2012_pop = df_2012.merge(df_pop_2012, left_on='Kommune', right_on='Kode')
# df_2013_pop = df_2013.merge(df_pop_2013, left_on='Kommune', right_on='Kode')
# df_2014_pop = df_2014.merge(df_pop_2014, left_on='Kommune', right_on='Kode')
df_2015_pop = df_2015.merge(df_pop_2015, left_on='Kommune', right_on='Kode')
df_2016_pop = df_2016.merge(df_pop_2016, left_on='Kommune', right_on='Kode')
df_2017_pop = df_2017.merge(df_pop_2017, left_on='Kommune', right_on='Kode')
df_2018_pop = df_2018.merge(df_pop_2018, left_on='Kommune', right_on='Kode')

# Kun interesseret i antal pr kommune og kommune demografi/population - ikke individuelle apoteker
#df_2008_pop_reduced = df_2008_pop.drop_duplicates(subset=['Kode'])
#df_2009_pop_reduced = df_2009_pop.drop_duplicates(subset=['Kode'])
# df_2010_pop_reduced = df_2010_pop.drop_duplicates(subset=['Kode'])
# df_2011_pop_reduced = df_2011_pop.drop_duplicates(subset=['Kode'])
# df_2012_pop_reduced = df_2012_pop.drop_duplicates(subset=['Kode'])
# df_2013_pop_reduced = df_2013_pop.drop_duplicates(subset=['Kode'])
# df_2014_pop_reduced = df_2014_pop.drop_duplicates(subset=['Kode'])
df_2015_pop_reduced = df_2015_pop.drop_duplicates(subset=['Kode'])
df_2016_pop_reduced = df_2016_pop.drop_duplicates(subset=['Kode'])
df_2017_pop_reduced = df_2017_pop.drop_duplicates(subset=['Kode'])
df_2018_pop_reduced = df_2018_pop.drop_duplicates(subset=['Kode'])

# Note: der er 97 fordi Læse og Christiansø ikke er der?
# Out:
# C:\Users\Oliver\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Oliver\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Oliver\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Drop uinterresante variable:
#df_bres_2008 = df_2008_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
#df_bres_2009 = df_2009_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
#df_bres_2010 = df_2010_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
#df_bres_2011 = df_2011_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
#df_bres_2012 = df_2012_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
#df_bres_2013 = df_2013_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
#df_bres_2014 = df_2014_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2015 = df_2015_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2016 = df_2016_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2017 = df_2017_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2018 = df_2018_pop_reduced.drop(['VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'Kommune_x', 'amt', 'PostNr', 'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
# Eksempel på datasæt:
#df_bres_samlet =

# %%
frames = [ df_bres_2015, df_bres_2016, df_bres_2017, df_bres_2018]#df_bres_2010, df_bres_2011, df_bres_2012, df_bres_2013, df_bres_2014, df_bres_2015, df_bres_2016, df_bres_2017, df_bres_2018]
df_bres_samlet = pd.concat(frames)

# %%
df_bres_samlet.to_csv('Bresnahan_data_2.csv')

# %%
#### TIl BY MARKEDER  #####

# %%
df_byer_2 =  pd.read_excel("Bymarkeder_unikpost.xlsx")
df_byer_2 = df_byer_2.rename(columns = {'kommune': 'Kommune'})

# %%
df_byer_2010 = df_byer_2.drop(['2011', '2012', '2013', '2014','2015', '2016', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2011 = df_byer_2.drop(['2010', '2012', '2013', '2014','2015', '2016', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2012 = df_byer_2.drop(['2011', '2010', '2013', '2014','2015', '2016', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2013 = df_byer_2.drop(['2011', '2012', '2010', '2014','2015', '2016', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2014 = df_byer_2.drop(['2011', '2012', '2013', '2010','2015', '2016', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2015 = df_byer_2.drop(['2011', '2012', '2013', '2014','2010', '2016', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2016 = df_byer_2.drop(['2011', '2012', '2013', '2014','2015', '2010', '2017', '2018', '2019', '2020'], axis =1)
df_byer_2017 = df_byer_2.drop(['2011', '2012', '2013', '2014','2015', '2016', '2010', '2018', '2019', '2020'], axis =1)
df_byer_2018 = df_byer_2.drop(['2011', '2012', '2013', '2014','2015', '2016', '2017', '2010', '2019', '2020'], axis =1)

# %%
df_2010_post = df_2010_ny
df_2011_post = df_2011_ny
df_2012_post = df_2012_ny
df_2013_post = df_2013_ny
df_2014_post = df_2014_ny
df_2015_post = df_2015_ny
df_2016_post = df_2016_ny
df_2017_post = df_2017_ny
df_2018_post = df_2018_ny

# %%
# df_2010_post['antal_apo']=df_2010_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2010_post['År'] = 2010
# df_2011_post['antal_apo']=df_2011_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2011_post['År'] = 2011
# df_2012_post['antal_apo']=df_2012_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2012_post['År'] = 2012
# df_2013_post['antal_apo']=df_2013_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2013_post['År'] = 2013
# df_2014_post['antal_apo']=df_2014_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2014_post['År'] = 2014
# df_2015_post['antal_apo']=df_2015_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2015_post['År'] = 2015
# df_2016_post['antal_apo']=df_2016_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2016_post['År'] = 2016
# df_2017_post['antal_apo']=df_2017_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2017_post['År'] = 2017
# df_2018_post['antal_apo']=df_2018_ny.groupby(by='PostNr')['ApotekNr'].transform('count')
df_2018_post['År'] = 2018

# %%
df_2010_reduced_post = df_2010_post.drop_duplicates(subset=['Kommune'])
df_2011_reduced_post = df_2011_post.drop_duplicates(subset=['Kommune'])
df_2012_reduced_post = df_2012_post.drop_duplicates(subset=['Kommune'])
df_2013_reduced_post = df_2013_post.drop_duplicates(subset=['Kommune'])
df_2014_reduced_post = df_2014_post.drop_duplicates(subset=['Kommune'])
df_2015_reduced_post = df_2015_post.drop_duplicates(subset=['Kommune'])
df_2016_reduced_post = df_2016_post.drop_duplicates(subset=['Kommune'])
df_2017_reduced_post = df_2017_post.drop_duplicates(subset=['Kommune'])
df_2018_reduced_post = df_2018_post.drop_duplicates(subset=['Kommune'])

# %%
df_bres_2008_ny_post = df_2008_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2009_ny_post = df_2009_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2010_ny_post = df_2010_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2011_ny_post = df_2011_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2012_ny_post = df_2012_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2013_ny_post = df_2013_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2014_ny_post = df_2014_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2015_ny_post = df_2015_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2016_ny_post = df_2016_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2017_ny_post = df_2017_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_bres_2018_ny_post = df_2018_post.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)

# %%
#df_byer_2010
# jeg vil gerne give hver række værdier fra kolonner d65, d17, samlet_ind, markedsvaerdi,x, yderkom 
#df_byer_2010['d65']=df_bres_2010_ny_post.groupby(by='Kommune')['ApotekNr']
df_byer_2010 = df_byer_2010.merge(df_2010_reduced_post, on='Kommune')
df_byer_2011 = df_byer_2011.merge(df_2011_reduced_post, on='Kommune')
df_byer_2012 = df_byer_2012.merge(df_2012_reduced_post, on='Kommune')
df_byer_2013 = df_byer_2013.merge(df_2013_reduced_post, on='Kommune')
df_byer_2014 = df_byer_2014.merge(df_2014_reduced_post, on='Kommune')
df_byer_2015 = df_byer_2015.merge(df_2015_reduced_post, on='Kommune')
df_byer_2016 = df_byer_2016.merge(df_2016_reduced_post, on='Kommune')
df_byer_2017 = df_byer_2017.merge(df_2017_reduced_post, on='Kommune')
df_byer_2018 = df_byer_2018.merge(df_2018_reduced_post, on='Kommune')

# %%
df_byer_2010_drop = df_byer_2010.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2011_drop = df_byer_2011.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2012_drop = df_byer_2012.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2013_drop = df_byer_2013.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2014_drop = df_byer_2014.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2015_drop = df_byer_2015.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2016_drop = df_byer_2016.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2017_drop = df_byer_2017.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)
df_byer_2018_drop = df_byer_2018.drop(['GNS_OMS', 'GNS_MED_PROFIT', 'VAR1','PostNr','antal_apo', 'ApotekNr', 'Navn', 'TypeID', 'Adresse', 'Startdato', 'Slutdato', 'amt',  'Region', 'Adresse_v2', 'latitudes',  'Stdato', 'Sldato', 'Styear', 'Sldato', 'dummy', 'longitudes', 'Slyear', 'geometry', 'Year'], axis=1)

# %%
df_byer_2010_drop = df_byer_2010_drop.rename(columns={'2010':'By_befolkning'})
df_byer_2011_drop = df_byer_2011_drop.rename(columns={'2011':'By_befolkning'})
df_byer_2012_drop = df_byer_2012_drop.rename(columns={'2012':'By_befolkning'})
df_byer_2013_drop = df_byer_2013_drop.rename(columns={'2013':'By_befolkning'})
df_byer_2014_drop = df_byer_2014_drop.rename(columns={'2014':'By_befolkning'})
df_byer_2015_drop = df_byer_2015_drop.rename(columns={'2015':'By_befolkning'})
df_byer_2016_drop = df_byer_2016_drop.rename(columns={'2016':'By_befolkning'})
df_byer_2017_drop = df_byer_2017_drop.rename(columns={'2017':'By_befolkning'})
df_byer_2018_drop = df_byer_2018_drop.rename(columns={'2018':'By_befolkning'})

# %%
from tqdm import tqdm
#årstal = [df_byer_2010_drop, df_byer_2011_drop, df_byer_2012_drop, df_byer_2013_drop, df_byer_2014_drop, df_byer_2015_drop, df_byer_2016_drop, df_byer_2017_drop, df_byer_2018_drop]
årstallet = list(range(2010,2019))
årstal = {2010: df_byer_2010_drop, 2011:df_byer_2011_drop, 2012:df_byer_2012_drop, 2013:df_byer_2013_drop, 2014:df_byer_2014_drop, 2015:df_byer_2015_drop, 2016:df_byer_2016_drop, 2017:df_byer_2017_drop, 2018:df_byer_2018_drop}
årstal_opslag ={2010:df_2010_ny, 2011:df_2011_ny, 2012:df_2012_ny, 2013:df_2013_ny, 2014:df_2014_ny, 2015:df_2015_ny, 2016:df_2016_ny, 2017:df_2017_ny, 2018:df_2018_ny}
antal_apo = []
count = 0


for år in tqdm(årstallet):
    antal_apo = []
    for postnr in range(len(årstal[år]['postnummer'])): #df_byer_2010_drop
        if type(årstal[år]['postnummer'][postnr]) is int:
            count = 0
            for postnummer in årstal_opslag[år]['PostNr']:
                if postnummer == årstal[år]['postnummer'][postnr]:
                    count+=1
            antal_apo.append(count)
        else:
#     if type(df_byer_2010_drop['postnummer'][postnr]) is str:
            count = 0
            for postnummer in årstal_opslag[år]['PostNr']:
                if str(postnummer) in årstal[år]['postnummer'][postnr]:
                    count+=1
            antal_apo.append(count)        
    årstal[år]['antal_apo'] = antal_apo
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:09<00:00,  1.23s/it]

# %%
frames_by = [ df_byer_2010_drop, df_byer_2011_drop, df_byer_2012_drop, df_byer_2013_drop, df_byer_2014_drop, df_byer_2015_drop, df_byer_2016_drop, df_byer_2017_drop, df_byer_2018_drop]#df_bres_2010, df_bres_2011, df_bres_2012, df_bres_2013, df_bres_2014, df_bres_2015, df_bres_2016, df_bres_2017, df_bres_2018]
df_bres_samlet_by = pd.concat(frames_by)

# %%
df_bres_samlet_by_fjernet_nr = df_bres_samlet_by.drop(columns = "postnummer")
df_bres_samlet_by_fjernet_nr.to_csv('Bresnahan_data_by.csv')

# %%
df_bres_samlet_by.to_excel('Bresnahan_data_by.xlsx')

# %%
df_bres_samlet_by_fjernet_n
# Out:
#      Kommune                 by  \
# 0        101          København
# 1        147      Frederiksberg
# 2        230          Rudersdal
# 3        240  Ølstykke-Stenløse
# 4        240              Veksø
# 5        461             Odense
# 6        461            Fraugde
# 7        751             Aarhus
# 8        751            Mårslet
# 9        751           Solbjerg
# 10       751              Trige
# 11       751             Harlev
# 12       751              Sabro
# 13       751            Lystrup
# 14       751          Hjortshøj
# 15       751             Løgten
# 16       730            Randers
# 17       730           Spentrup
# 18       730         Stevnstrup
# 19       851            Aalborg
# 20       851               Nibe
# 21       851            Gistrup
# 22       851             Klarup
# 23       851         Kongerslev
# 24       851            Gandrup
# 25       851          Vestbjerg
# 26       851            Sulsted
# 27       851           Tylstrup
# ...
